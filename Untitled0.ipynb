# %% [markdown]
# <a href="https://colab.research.google.com/github/noormalik33/AI-Infographics/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
os.makedirs('data', exist_ok=True)
os.makedirs('notebooks', exist_ok=True)
